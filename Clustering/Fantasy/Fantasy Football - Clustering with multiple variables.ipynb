# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale

# %%
contents = pd.read_csv('FPLdata.csv')
contents.head
# Out:
# <bound method NDFrame.head of                  Name Team Position  Cost  Creativity  Influence  Threat  \
# 0          Adam Smith  BOU      DEF    45       345.5      455.0   144.0
# 1              Adrian  WHU      GKP    45         0.0      470.4     0.0
# 2              Aguero  MCI      FWD   110       570.8      966.4  1484.0
# 3                 Ake  BOU      DEF    50       115.1      932.4   287.0
# 4          Albrighton  LEI      MID    55       718.3      580.0   300.0
# 5        Alderweireld  TOT      DEF    60        67.8      249.2    50.0
# 6    Alexander-Arnold  LIV      DEF    50       399.2      358.2   142.0
# 7             Alisson  LIV      GKP    55         0.0        0.0     0.0
# 8                Alli  TOT      MID    90       878.5      775.2   934.0
# 9              Alonso  CHE      DEF    65       549.6      697.8   822.0
# 10            Amartey  LEI      MID    45        10.3       81.2     0.0
# ...
